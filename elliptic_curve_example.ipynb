# %% [markdown]
# # Elliptic Curve

# %%
p, a, b = 71, 1, 0
E = EllipticCurve(GF(p), [a,b]);
print E
# Out:
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field of size 71
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field of size 71

# %%
E.points()
# Out:
# [(0 : 0 : 1), (0 : 1 : 0), (1 : 12 : 1), (1 : 59 : 1), (2 : 9 : 1), (2 : 62 : 1), (3 : 32 : 1), (3 : 39 : 1), (6 : 3 : 1), (6 : 68 : 1), (10 : 4 : 1), (10 : 67 : 1), (11 : 8 : 1), (11 : 63 : 1), (12 : 6 : 1), (12 : 65 : 1), (13 : 3 : 1), (13 : 68 : 1), (14 : 29 : 1), (14 : 42 : 1), (22 : 34 : 1), (22 : 37 : 1), (23 : 7 : 1), (23 : 64 : 1), (24 : 28 : 1), (24 : 43 : 1), (25 : 32 : 1), (25 : 39 : 1), (27 : 16 : 1), (27 : 55 : 1), (30 : 11 : 1), (30 : 60 : 1), (31 : 12 : 1), (31 : 59 : 1), (34 : 2 : 1), (34 : 69 : 1), (36 : 20 : 1), (36 : 51 : 1), (38 : 13 : 1), (38 : 58 : 1), (39 : 12 : 1), (39 : 59 : 1), (42 : 19 : 1), (42 : 52 : 1), (43 : 32 : 1), (43 : 39 : 1), (45 : 19 : 1), (45 : 52 : 1), (50 : 27 : 1), (50 : 44 : 1), (51 : 28 : 1), (51 : 43 : 1), (52 : 3 : 1), (52 : 68 : 1), (53 : 16 : 1), (53 : 55 : 1), (54 : 18 : 1), (54 : 53 : 1), (55 : 19 : 1), (55 : 52 : 1), (56 : 35 : 1), (56 : 36 : 1), (62 : 16 : 1), (62 : 55 : 1), (63 : 30 : 1), (63 : 41 : 1), (64 : 17 : 1), (64 : 54 : 1)
# ...

# %%
E.plot()
# Out:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive

# %%
P = E.point([1,12])
Q = E.point([63,41])

# %%
print 'P+Q =', (P + Q).xy()
# Out:
# P+Q = (13, 3)
# P+Q = (13, 3)

# %%
print '[3]P =', (3*P).xy()
# Out:
# [3]P = (1, 59)
# [3]P = (1, 59)

# %%
print 'j(E) =', E.j_invariant()

# %%
#for a in range(p):
#    for b in range(p):
#        if (27*b^2 + 4*a^3) % p != 0:
#            E2 = EllipticCurve(GF(p), [a,b])
#            j = E2.j_invariant()
#            if(j == 24):
#                print(E2.j_invariant(),E2.a4(),E2.a6())

# %%
E2 = EllipticCurve(GF(p), [70,0]);
print 'j(E2) =', E2.j_invariant()

# %%
print 'Are E and E2 isomorphic ?', E.is_isomorphic(E2)

# %%
print(E.is_supersingular())
E(0).division_points(p)
